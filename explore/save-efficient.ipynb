# %%
import hetmech.degree_weight
import hetmech.degree_group
from hetmech.hetmat import HetMat
import numpy 
import pandas
import scipy.sparse
import itertools
from hetmech.matrix import metaedge_to_adjacency_matrix

# %%
hetmat = HetMat('../data/hetionet-v1.0.hetmat/')

# %%
metapath = 'CbGaD'

# %%
def dwpc_to_degrees(graph, metapath, damping=0.5):
    metapath = graph.metagraph.get_metapath(metapath)
    _, _, source_adj_mat = metaedge_to_adjacency_matrix(graph, metapath[0], dense_threshold=0.7)
    _, _, target_adj_mat = metaedge_to_adjacency_matrix(graph, metapath[-1], dense_threshold=0.7)
    source_degrees = source_adj_mat.sum(axis=1).flat
    target_degrees = target_adj_mat.sum(axis=0).flat
    del source_adj_mat, target_adj_mat

    source_path = graph.get_nodes_path(metapath.source(), file_format='tsv')
    source_node_df = pandas.read_table(source_path)
    source_node_names = list(source_node_df['name'])

    target_path = graph.get_nodes_path(metapath.target(), file_format='tsv')
    target_node_df = pandas.read_table(target_path)
    target_node_names = list(target_node_df['name'])

    row_names, col_names, dwpc_matrix = graph.read_path_counts(metapath, 'dwpc', damping)
    dwpc_matrix = numpy.arcsinh(dwpc_matrix / dwpc_matrix.mean())
    if scipy.sparse.issparse(dwpc_matrix):
        dwpc_matrix = dwpc_matrix.toarray()

    _, _, path_count = graph.read_path_counts(metapath, 'dwpc', 0.0)
    if scipy.sparse.issparse(path_count):
        path_count = path_count.toarray()

    row_inds, col_inds = range(len(row_names)), range(len(col_names))
    for row in itertools.product(row_inds, col_inds):
        row_ind, col_ind = row
        row = {
            'source_id': row_names[row_ind],
            'source_name': source_node_names[row_ind],
            'target_name': target_node_names[col_ind],
            'target_id': col_names[col_ind],
            'source_degree': source_degrees[row_ind],
            'target_degree': target_degrees[col_ind],
            'dwpc': dwpc_matrix[row_ind, col_ind],
            'path-count': path_count[row_ind, col_ind],
        }
        yield row
        continue

# %%
# %%time
pandas.DataFrame(dwpc_to_degrees(hetmat, metapath))
# Out:
# CPU times: user 634 ms, sys: 35.5 ms, total: 669 ms
# Wall time: 669 ms
#             dwpc  path-count  source_degree source_id source_name  \
# 0       0.000000           0              2   DB00014   Goserelin
# 1       0.000000           0              2   DB00014   Goserelin
# 2       0.000000           0              2   DB00014   Goserelin
# 3       0.000000           0              2   DB00014   Goserelin
# 4       0.000000           0              2   DB00014   Goserelin
# 5       0.000000           0              2   DB00014   Goserelin
# 6       0.000000           0              2   DB00014   Goserelin
# 7       0.000000           0              2   DB00014   Goserelin
# 8       0.000000           0              2   DB00014   Goserelin
# 9       0.000000           0              2   DB00014   Goserelin
# 10      0.000000           0              2   DB00014   Goserelin
# 11      0.000000           0              2   DB00014   Goserelin
# 12      0.000000           0              2   DB00014   Goserelin
# 13      0.000000           0              2   DB00014   Goserelin
# 14      0.000000           0              2   DB00014   Goserelin
# 15      0.000000           0              2   DB00014   Goserelin
# 16      0.000000           0              2   DB00014   Goserelin
# 17      0.000000           0              2   DB00014   Goserelin
# 18      0.000000           0              2   DB00014   Goserelin
# 19      0.000000           0              2   DB00014   Goserelin
# 20      0.000000           0              2   DB00014   Goserelin
# 21      0.000000           0              2   DB00014   Goserelin
# 22      0.000000           0              2   DB00014   Goserelin
# 23      0.000000           0              2   DB00014   Goserelin
# 24      0.000000           0              2   DB00014   Goserelin
# 25      4.967856           1              2   DB00014   Goserelin
# 26      0.000000           0              2   DB00014   Goserelin
# 27      0.000000           0              2   DB00014   Goserelin
# 28      0.000000           0              2   DB00014   Goserelin
# 29      0.000000           0              2   DB00014   Goserelin
# ...          ...         ...            ...       ...         ...
# 212594  4.155270           4              6   DB09028    Cytisine
# 212595  0.000000           0              6   DB09028    Cytisine
# 212596  0.000000           0              6   DB09028    Cytisine
# 212597  0.000000           0              6   DB09028    Cytisine
# 212598  0.000000           0              6   DB09028    Cytisine
# 212599  0.000000           0              6   DB09028    Cytisine
# 212600  0.000000           0              6   DB09028    Cytisine
# 212601  0.000000           0              6   DB09028    Cytisine
# 212602  0.000000           0              6   DB09028    Cytisine
# 212603  0.000000           0              6   DB09028    Cytisine
# 212604  0.000000           0              6   DB09028    Cytisine
# 212605  0.000000           0              6   DB09028    Cytisine
# 212606  0.000000           0              6   DB09028    Cytisine
# 212607  0.000000           0              6   DB09028    Cytisine
# 212608  0.000000           0              6   DB09028    Cytisine
# 212609  0.000000           0              6   DB09028    Cytisine
# 212610  0.000000           0              6   DB09028    Cytisine
# 212611  0.000000           0              6   DB09028    Cytisine
# 212612  0.000000           0              6   DB09028    Cytisine
# 212613  0.000000           0              6   DB09028    Cytisine
# 212614  0.000000           0              6   DB09028    Cytisine
# 212615  0.000000           0              6   DB09028    Cytisine
# 212616  0.000000           0              6   DB09028    Cytisine
# 212617  0.000000           0              6   DB09028    Cytisine
# 212618  0.000000           0              6   DB09028    Cytisine
# 212619  0.000000           0              6   DB09028    Cytisine
# 212620  0.000000           0              6   DB09028    Cytisine
# 212621  0.000000           0              6   DB09028    Cytisine
# 212622  0.000000           0              6   DB09028    Cytisine
# 212623  0.000000           0              6   DB09028    Cytisine
#
#         target_degree     target_id                               target_name
# 0                  18  DOID:0050156             idiopathic pulmonary fibrosis
# 1                  12  DOID:0050425                    restless legs syndrome
# 2                  49  DOID:0050741                        alcohol dependence
# 3                  19  DOID:0050742                       nicotine dependence
# 4                   9  DOID:0060073                   lymphatic system cancer
# 5                  16  DOID:0060119                            pharynx cancer
# 6                   4    DOID:10021                           duodenum cancer
# 7                   0    DOID:10153                              ileum cancer
# 8                  23     DOID:1024                                   leprosy
# 9                 535    DOID:10283                           prostate cancer
# 10                298    DOID:10534                            stomach cancer
# 11                 48    DOID:10608                            celiac disease
# 12                196    DOID:10652                       Alzheimer's disease
# 13                496    DOID:10763                              hypertension
# 14                  4    DOID:10811                       nasal cavity cancer
# 15                 55    DOID:10871          age related macular degeneration
# 16                 41     DOID:1094  attention deficit hyperactivity disorder
# 17                 23    DOID:10941                     intracranial aneurysm
# 18                 27    DOID:10976             membranous glomerulonephritis
# 19                121    DOID:11054                    urinary bladder cancer
# 20                 16    DOID:11119            Gilles de la Tourette syndrome
# 21                 69     DOID:1115                                   sarcoma
# 22                  4    DOID:11239                           appendix cancer
# 23                 98    DOID:11476                              osteoporosis
# 24                  6    DOID:11555              Fuchs' endothelial dystrophy
# 25                200    DOID:11612                 polycystic ovary syndrome
# 26                  2    DOID:11615                             penile cancer
# 27                 17    DOID:11714                      gestational diabetes
# 28                  1    DOID:11819                             ureter cancer
# 29                  3      DOID:119                            vaginal cancer
# ...               ...           ...                                       ...
# 212594            235     DOID:5419                             schizophrenia
# 212595              1     DOID:5559                        mediastinal cancer
# 212596              7     DOID:5612                             spinal cancer
# 212597             26      DOID:585                           nephrolithiasis
# 212598              3     DOID:5875                    retroperitoneal cancer
# 212599             16      DOID:594                            panic disorder
# 212600             40      DOID:635        acquired immunodeficiency syndrome
# 212601             46     DOID:6364                                  migraine
# 212602             33     DOID:7147                    ankylosing spondylitis
# 212603            267     DOID:7148                      rheumatoid arthritis
# 212604             24     DOID:7693                 abdominal aortic aneurysm
# 212605            132      DOID:784                    chronic kidney failure
# 212606             59      DOID:824                             periodontitis
# 212607             62     DOID:8398                            osteoarthritis
# 212608            121     DOID:8577                        ulcerative colitis
# 212609            120     DOID:8778                           Crohn's disease
# 212610            118     DOID:8850                     salivary gland cancer
# 212611             92     DOID:8893                                 psoriasis
# 212612             27     DOID:8986                                narcolepsy
# 212613             14       DOID:90                 degenerative disc disease
# 212614             26     DOID:9008                       psoriatic arthritis
# 212615            155     DOID:9074              systemic lupus erythematosus
# 212616             24     DOID:9206                       Barrett's esophagus
# 212617             54     DOID:9296                                 cleft lip
# 212618            275     DOID:9352                  type 2 diabetes mellitus
# 212619            131     DOID:9744                  type 1 diabetes mellitus
# 212620             98     DOID:9835                          refractive error
# 212621             12      DOID:986                           alopecia areata
# 212622              0     DOID:9917                            pleural cancer
# 212623            373     DOID:9970                                   obesity
#
# [212624 rows x 8 columns]

# %%
def dwpc_to_degrees(graph, metapath, damping=0.5):
    metapath = graph.metagraph.get_metapath(metapath)
    _, _, source_adj_mat = metaedge_to_adjacency_matrix(graph, metapath[0], dense_threshold=0.7)
    _, _, target_adj_mat = metaedge_to_adjacency_matrix(graph, metapath[-1], dense_threshold=0.7)
    source_degrees = source_adj_mat.sum(axis=1).flat
    target_degrees = target_adj_mat.sum(axis=0).flat
    del source_adj_mat, target_adj_mat

    source_path = graph.get_nodes_path(metapath.source(), file_format='tsv')
    source_node_df = pandas.read_table(source_path)
    source_node_names = list(source_node_df['name'])

    target_path = graph.get_nodes_path(metapath.target(), file_format='tsv')
    target_node_df = pandas.read_table(target_path)
    target_node_names = list(target_node_df['name'])

    row_names, col_names, dwpc_matrix = graph.read_path_counts(metapath, 'dwpc', damping)
    dwpc_matrix = numpy.arcsinh(dwpc_matrix / dwpc_matrix.mean())
    dwpc_matrix = scipy.sparse.coo_matrix(dwpc_matrix)

    _, _, path_count = graph.read_path_counts(metapath, 'dwpc', 0.0)
    path_count = scipy.sparse.coo_matrix(dwpc_matrix)

    indices = range(dwpc_matrix.nnz)
    for ind in indices:
        row_ind = dwpc_matrix.row[ind]
        col_ind = dwpc_matrix.col[ind]
        row = {
            'source_id': row_names[row_ind],
            'source_name': source_node_names[row_ind],
            'target_name': target_node_names[col_ind],
            'target_id': col_names[col_ind],
            'source_degree': source_degrees[row_ind],
            'target_degree': target_degrees[col_ind],
            'dwpc': dwpc_matrix.data[ind],
            'path-count': path_count.data[ind],
        }
        yield row
        continue

# %%
# %%time
# 27492  3.047427    3.047427              6   DB09028      Cytisine
# 27493  3.753859    3.753859              6   DB09028      Cytisine
# 27494  2.494473    2.494473              6   DB09028      Cytisine
# 27495  2.820937    2.820937              6   DB09028      Cytisine
# 27496  3.399008    3.399008              6   DB09028      Cytisine
# 27497  4.155270    4.155270              6   DB09028      Cytisine
#
#        target_degree     target_id                               target_name
# 0                200    DOID:11612                 polycystic ovary syndrome
# 1                 38     DOID:3953                      adrenal gland cancer
# 2                535    DOID:10283                           prostate cancer
# 3                298    DOID:10534                            stomach cancer
# 4                196    DOID:10652                       Alzheimer's disease
# 5                496    DOID:10763                              hypertension
# 6                121    DOID:11054                    urinary bladder cancer
# 7                 55    DOID:11934                      head and neck cancer
# 8                253    DOID:12849                         autistic disorder
# 9                252     DOID:1324                               lung cancer
# 10                90    DOID:14221                      metabolic syndrome X
# 11               540     DOID:1612                             breast cancer
# 12               109     DOID:1686                                  glaucoma
# 13                58     DOID:1781                            thyroid cancer
# 14               142     DOID:1793                         pancreatic cancer
# 15               399     DOID:1826                         epilepsy syndrome
# 16                74      DOID:184                               bone cancer
# 17               342     DOID:1909                                  melanoma
# 18               165     DOID:1936                           atherosclerosis
# 19                63      DOID:219                              colon cancer
# 20               213      DOID:263                             kidney cancer
# 21               222     DOID:2841                                    asthma
# 22               181     DOID:3070                          malignant glioma
# 23               114      DOID:332             amyotrophic lateral sclerosis
# 24               478     DOID:3393                   coronary artery disease
# 25                38     DOID:3953                      adrenal gland cancer
# 26                42     DOID:4045                             muscle cancer
# 27                69     DOID:4159                               skin cancer
# 28                42     DOID:4606                          bile duct cancer
# 29               103     DOID:4989                              pancreatitis
# ...              ...           ...                                       ...
# 27468             16    DOID:11119            Gilles de la Tourette syndrome
# 27469            253    DOID:12849                         autistic disorder
# 27470             90    DOID:14221                      metabolic syndrome X
# 27471            143    DOID:14330                       Parkinson's disease
# 27472             33     DOID:1595                     endogenous depression
# 27473             93     DOID:3312                          bipolar disorder
# 27474            114      DOID:332             amyotrophic lateral sclerosis
# 27475            235     DOID:5419                             schizophrenia
# 27476             46     DOID:6364                                  migraine
# 27477            275     DOID:9352                  type 2 diabetes mellitus
# 27478            373     DOID:9970                                   obesity
# 27479            200    DOID:11612                 polycystic ovary syndrome
# 27480             49  DOID:0050741                        alcohol dependence
# 27481             19  DOID:0050742                       nicotine dependence
# 27482            496    DOID:10763                              hypertension
# 27483             41     DOID:1094  attention deficit hyperactivity disorder
# 27484             16    DOID:11119            Gilles de la Tourette syndrome
# 27485            143    DOID:14330                       Parkinson's disease
# 27486             93     DOID:3312                          bipolar disorder
# 27487            235     DOID:5419                             schizophrenia
# 27488            373     DOID:9970                                   obesity
# 27489             19  DOID:0050742                       nicotine dependence
# 27490            196    DOID:10652                       Alzheimer's disease
# 27491             41     DOID:1094  attention deficit hyperactivity disorder
# 27492            253    DOID:12849                         autistic disorder
# 27493            252     DOID:1324                               lung cancer
# 27494            143    DOID:14330                       Parkinson's disease
# 27495            399     DOID:1826                         epilepsy syndrome
# 27496             77     DOID:3083     chronic obstructive pulmonary disease
# 27497            235     DOID:5419                             schizophrenia
#
# [27498 rows x 8 columns]
