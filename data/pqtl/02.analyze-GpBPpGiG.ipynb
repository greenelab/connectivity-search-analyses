# %% [markdown]
# # Identify canidate causal genes for pQTLs

# %%
import pandas
import numpy

import hetmech.hetmat

# %% [markdown]
# ## Read pQTL associations and candidate genes

# %%
pqtl_df = pandas.read_table('pqtl.tsv')
loci_df = pandas.read_table('snps-to-locus-genes.tsv')
loci_df = loci_df.drop_duplicates()
snp_df = pqtl_df.merge(loci_df)
# Drop protein complexes
snp_df = snp_df.dropna(subset=['pqtl_entrez_id', 'locus_entrez_id'])
snp_df = snp_df[~snp_df.pqtl_entrez_id.str.contains(',')]
for col in 'pqtl_entrez_id', 'locus_entrez_id':
    snp_df[col] = snp_df[col].astype(int)
snp_df.head(2)
# Out:
#         snp pqtl_gene  pqtl_entrez_id  neg_log10_p gwas_source locus_gene  \
# 0  rs651007      SELE            6401      102.728    23300549        ABO
# 1  rs651007      SELE            6401      102.728    23300549      SURF6
#
#    locus_entrez_id  distance_to_snp
# 0               28             3217
# 1             6838            50343

# %% [markdown]
# ## Compute hetnet features

# %%
hetmat = hetmech.hetmat.HetMat('../hetionet-v1.0.hetmat/')

# %%
metapath = 'GpBPpGiG'

# %%
# Memory efficient reading (drop DWPC rows for unobserved gene-pairs)
gene_pairs = set(zip(snp_df.pqtl_entrez_id, snp_df.locus_entrez_id))
path = hetmat.directory.joinpath('adjusted-path-counts', 'dwpc-0.5', 'adjusted-dwpcs', f'{metapath}-filtered.tsv.gz')
chunks = pandas.read_table(path, chunksize=100_000)
dfs = list()
for df in chunks:
    keep = [pair in gene_pairs for pair in zip(df.source_id, df.target_id)]
    dfs.append(df.loc[keep, :])
dwpc_df = pandas.concat(dfs)
len(dwpc_df)
# Out:
# 5580

# %%
dwpc_df.head()
# Out:
#       source_id  target_id source_name target_name  source_degree  \
# 2804         12       5104    SERPINA3    SERPINA5             19
# 2816         12       5265    SERPINA3    SERPINA1             19
# 3306         12      57062    SERPINA3       DDX24             19
# 7788         16       6203        AARS        RPS9             58
# 8203         16      10990        AARS      LILRB5             58
#
#       target_degree  path_count      dwpc         n       nnz  n_perms  \
# 2804             22          18  2.794127   7219200   7218939      200
# 2816             37          12  2.928520   3276800   3276600      200
# 3306             43          44  2.970499   1843200   1843200      200
# 7788            262        1029  3.614633     44400     44400      200
# 8203              1           9  1.616004  36748400  31504598      200
#
#        mean_nz     sd_nz   p_value
# 2804  1.384344  0.507804  0.011239
# 2816  1.671001  0.446058  0.008134
# 3306  1.755517  0.426618  0.007159
# 7788  3.361336  0.146249  0.044126
# 8203  0.401718  0.489000  0.027999

# %%
snp_dwpc_df = (
    snp_df
    .merge(dwpc_df, left_on=['pqtl_entrez_id', 'locus_entrez_id'], right_on=['source_id', 'target_id'], how='left')
    .drop(columns=['source_id', 'target_id', 'source_name', 'target_name'])
)
snp_dwpc_df.head(2)
# Out:
#         snp pqtl_gene  pqtl_entrez_id  neg_log10_p gwas_source locus_gene  \
# 0  rs651007      SELE            6401      102.728    23300549        ABO
# 1  rs651007      SELE            6401      102.728    23300549      SURF6
#
#    locus_entrez_id  distance_to_snp  source_degree  target_degree  path_count  \
# 0               28             3217            NaN            NaN         NaN
# 1             6838            50343            NaN            NaN         NaN
#
#    dwpc   n  nnz  n_perms  mean_nz  sd_nz  p_value
# 0   NaN NaN  NaN      NaN      NaN    NaN      NaN
# 1   NaN NaN  NaN      NaN      NaN    NaN      NaN

# %%
snp_dwpc_df.to_csv('candidates-GpBPpGiG.tsv', index=False, sep='\t')

# %% [markdown]
# ## Potential candidates of interest

# %%
groups = snp_dwpc_df.groupby(['gwas_source', 'snp', 'pqtl_gene'])
groups = [df for i, df in groups]

# %%
groups[2]
# Out:
#                snp pqtl_gene  pqtl_entrez_id  neg_log10_p     gwas_source  \
# 118305  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118306  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118307  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118308  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118309  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118310  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118311  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118312  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118313  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118314  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118315  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118316  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118317  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118318  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118319  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118320  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118321  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118322  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118323  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118324  rs10127775    MAP2K4            6416       13.165  10.1101/086793
# 118325  rs10127775    MAP2K4            6416       13.165  10.1101/086793
#
#         locus_gene  locus_entrez_id  distance_to_snp  source_degree  \
# 118305      GALNT2             2590           102052           58.0
# 118306   LINC01736        101927532           152880            NaN
# 118307       PGBD5            79605           154440            NaN
# 118308   LINC01737        101927553           432618            NaN
# 118309        COG2            22796           482447            NaN
# 118310        URB2             9816           499843            NaN
# 118311       TAF5L            27097           533995            NaN
# 118312         AGT              183           542481            NaN
# 118313       CAPN9            10753           587342            NaN
# 118314      ABCB10            23456           601347            NaN
# 118315      NUP133            55746           651701            NaN
# 118316    C1orf198            84886           677077            NaN
# 118317  AL118511.1        101927604           714804            NaN
# 118318       ACTA1               58           725944            NaN
# 118319       TTC13            79573           746201            NaN
# 118320       CCSAP           126731           816748            NaN
# 118321        ARV1            64801           818939            NaN
# 118322       RAB4A             5867           854148            NaN
# 118323       SPHAR            10638           854538            NaN
# 118324      FAM89A           375061           858916            NaN
# 118325     MIR1182        100302132           859786            NaN
#
#         target_degree  path_count      dwpc           n         nnz  n_perms  \
# 118305            4.0        90.0  3.077606  14578000.0  14516202.0    200.0
# 118306            NaN         NaN       NaN         NaN         NaN      NaN
# 118307            NaN         NaN       NaN         NaN         NaN      NaN
# 118308            NaN         NaN       NaN         NaN         NaN      NaN
# 118309            NaN         NaN       NaN         NaN         NaN      NaN
# 118310            NaN         NaN       NaN         NaN         NaN      NaN
# 118311            NaN         NaN       NaN         NaN         NaN      NaN
# 118312            NaN         NaN       NaN         NaN         NaN      NaN
# 118313            NaN         NaN       NaN         NaN         NaN      NaN
# 118314            NaN         NaN       NaN         NaN         NaN      NaN
# 118315            NaN         NaN       NaN         NaN         NaN      NaN
# 118316            NaN         NaN       NaN         NaN         NaN      NaN
# 118317            NaN         NaN       NaN         NaN         NaN      NaN
# 118318            NaN         NaN       NaN         NaN         NaN      NaN
# 118319            NaN         NaN       NaN         NaN         NaN      NaN
# 118320            NaN         NaN       NaN         NaN         NaN      NaN
# 118321            NaN         NaN       NaN         NaN         NaN      NaN
# 118322            NaN         NaN       NaN         NaN         NaN      NaN
# 118323            NaN         NaN       NaN         NaN         NaN      NaN
# 118324            NaN         NaN       NaN         NaN         NaN      NaN
# 118325            NaN         NaN       NaN         NaN         NaN      NaN
#
#          mean_nz     sd_nz   p_value
# 118305  0.992799  0.590786  0.005898
# 118306       NaN       NaN       NaN
# 118307       NaN       NaN       NaN
# 118308       NaN       NaN       NaN
# 118309       NaN       NaN       NaN
# 118310       NaN       NaN       NaN
# 118311       NaN       NaN       NaN
# 118312       NaN       NaN       NaN
# 118313       NaN       NaN       NaN
# 118314       NaN       NaN       NaN
# 118315       NaN       NaN       NaN
# 118316       NaN       NaN       NaN
# 118317       NaN       NaN       NaN
# 118318       NaN       NaN       NaN
# 118319       NaN       NaN       NaN
# 118320       NaN       NaN       NaN
# 118321       NaN       NaN       NaN
# 118322       NaN       NaN       NaN
# 118323       NaN       NaN       NaN
# 118324       NaN       NaN       NaN
# 118325       NaN       NaN       NaN

# %%
groups[7]
# Out:
#                snp pqtl_gene  pqtl_entrez_id  neg_log10_p     gwas_source  \
# 111938  rs10494745       HPX            3263       66.571  10.1101/086793
# 111939  rs10494745       HPX            3263       66.571  10.1101/086793
# 111940  rs10494745       HPX            3263       66.571  10.1101/086793
# 111941  rs10494745       HPX            3263       66.571  10.1101/086793
# 111942  rs10494745       HPX            3263       66.571  10.1101/086793
# 111943  rs10494745       HPX            3263       66.571  10.1101/086793
# 111944  rs10494745       HPX            3263       66.571  10.1101/086793
# 111945  rs10494745       HPX            3263       66.571  10.1101/086793
# 111946  rs10494745       HPX            3263       66.571  10.1101/086793
# 111947  rs10494745       HPX            3263       66.571  10.1101/086793
# 111948  rs10494745       HPX            3263       66.571  10.1101/086793
# 111949  rs10494745       HPX            3263       66.571  10.1101/086793
# 111950  rs10494745       HPX            3263       66.571  10.1101/086793
# 111951  rs10494745       HPX            3263       66.571  10.1101/086793
# 111952  rs10494745       HPX            3263       66.571  10.1101/086793
#
#        locus_gene  locus_entrez_id  distance_to_snp  source_degree  \
# 111938      CFHR4            10877              645           79.0
# 111939      CFHR2             3080            25445            NaN
# 111940      CFHR5            81494            59229           79.0
# 111941      CFHR1             3078            86138           79.0
# 111942       F13B             2165           120864            NaN
# 111943      CFHR3            10878           122921           79.0
# 111944       ASPM           259266           165801            NaN
# 111945        CFH             3075           170823           79.0
# 111946     ZBTB41           360023           235353            NaN
# 111947      KCNT2           343450           309102            NaN
# 111948    MIR4735        100616363           335846            NaN
# 111949       CRB1            23418           349877            NaN
# 111950    DENND1B           163486           586421            NaN
# 111951    C1orf53           388722           984320            NaN
# 111952       LHX9            56956           993575            NaN
#
#         target_degree  path_count      dwpc           n         nnz  n_perms  \
# 111938            3.0        30.0  3.611719   7830600.0   7770566.0    200.0
# 111939            NaN         NaN       NaN         NaN         NaN      NaN
# 111940            1.0        23.0  4.141619  15394600.0  13574476.0    200.0
# 111941            4.0        28.0  2.768193   6107000.0   6095144.0    200.0
# 111942            NaN         NaN       NaN         NaN         NaN      NaN
# 111943            2.0        24.0  3.803143   9938600.0   9638663.0    200.0
# 111944            NaN         NaN       NaN         NaN         NaN      NaN
# 111945           18.0       108.0  3.687287   1178000.0   1177800.0    200.0
# 111946            NaN         NaN       NaN         NaN         NaN      NaN
# 111947            NaN         NaN       NaN         NaN         NaN      NaN
# 111948            NaN         NaN       NaN         NaN         NaN      NaN
# 111949            NaN         NaN       NaN         NaN         NaN      NaN
# 111950            NaN         NaN       NaN         NaN         NaN      NaN
# 111951            NaN         NaN       NaN         NaN         NaN      NaN
# 111952            NaN         NaN       NaN         NaN         NaN      NaN
#
#          mean_nz     sd_nz   p_value
# 111938  0.964608  0.603812  0.001982
# 111939       NaN       NaN       NaN
# 111940  0.452063  0.511281  0.000365
# 111941  1.121360  0.591223  0.014682
# 111942       NaN       NaN       NaN
# 111943  0.761329  0.597103  0.001280
# 111944       NaN       NaN       NaN
# 111945  2.007228  0.397697  0.000253
# 111946       NaN       NaN       NaN
# 111947       NaN       NaN       NaN
# 111948       NaN       NaN       NaN
# 111949       NaN       NaN       NaN
# 111950       NaN       NaN       NaN
# 111951       NaN       NaN       NaN
# 111952       NaN       NaN       NaN

# %%
groups[8]
# Out:
#                snp pqtl_gene  pqtl_entrez_id  neg_log10_p     gwas_source  \
# 114634  rs10737680       CFH            3075        35.89  10.1101/086793
# 114635  rs10737680       CFH            3075        35.89  10.1101/086793
# 114636  rs10737680       CFH            3075        35.89  10.1101/086793
# 114637  rs10737680       CFH            3075        35.89  10.1101/086793
# 114638  rs10737680       CFH            3075        35.89  10.1101/086793
# 114639  rs10737680       CFH            3075        35.89  10.1101/086793
# 114640  rs10737680       CFH            3075        35.89  10.1101/086793
# 114641  rs10737680       CFH            3075        35.89  10.1101/086793
# 114642  rs10737680       CFH            3075        35.89  10.1101/086793
# 114643  rs10737680       CFH            3075        35.89  10.1101/086793
# 114644  rs10737680       CFH            3075        35.89  10.1101/086793
# 114645  rs10737680       CFH            3075        35.89  10.1101/086793
# 114646  rs10737680       CFH            3075        35.89  10.1101/086793
#
#        locus_gene  locus_entrez_id  distance_to_snp  source_degree  \
# 114634        CFH             3075            37179            NaN
# 114635      CFHR3            10878            64470           21.0
# 114636      KCNT2           343450           101100            NaN
# 114637      CFHR1             3078           109432           21.0
# 114638    MIR4735        100616363           127844            NaN
# 114639      CFHR4            10877           139916           21.0
# 114640      CFHR2             3080           233447            NaN
# 114641      CFHR5            81494           267231           21.0
# 114642       F13B             2165           328866           21.0
# 114643       ASPM           259266           373803            NaN
# 114644     ZBTB41           360023           443355            NaN
# 114645       CRB1            23418           557879            NaN
# 114646    DENND1B           163486           794423            NaN
#
#         target_degree  path_count      dwpc            n         nnz  n_perms  \
# 114634            NaN         NaN       NaN          NaN         NaN      NaN
# 114635            2.0        21.0  4.320710   75020400.0  65062638.0    200.0
# 114636            NaN         NaN       NaN          NaN         NaN      NaN
# 114637            4.0        16.0  1.846759   46098000.0  44387506.0    200.0
# 114638            NaN         NaN       NaN          NaN         NaN      NaN
# 114639            3.0        27.0  4.141113   59108400.0  55000247.0    200.0
# 114640            NaN         NaN       NaN          NaN         NaN      NaN
# 114641            1.0        21.0  4.667195  116204400.0  86925262.0    200.0
# 114642            2.0         3.0  2.218504   75020400.0  65062638.0    200.0
# 114643            NaN         NaN       NaN          NaN         NaN      NaN
# 114644            NaN         NaN       NaN          NaN         NaN      NaN
# 114645            NaN         NaN       NaN          NaN         NaN      NaN
# 114646            NaN         NaN       NaN          NaN         NaN      NaN
#
#          mean_nz     sd_nz   p_value
# 114634       NaN       NaN       NaN
# 114635  0.449195  0.527825  0.000367
# 114636       NaN       NaN       NaN
# 114637  0.647093  0.568289  0.041769
# 114638       NaN       NaN       NaN
# 114639  0.558740  0.555346  0.000531
# 114640       NaN       NaN       NaN
# 114641  0.273747  0.431237  0.000104
# 114642  0.449195  0.527825  0.012727
# 114643       NaN       NaN       NaN
# 114644       NaN       NaN       NaN
# 114645       NaN       NaN       NaN
# 114646       NaN       NaN       NaN
